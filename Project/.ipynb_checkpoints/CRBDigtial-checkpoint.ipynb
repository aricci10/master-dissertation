# %%
import numpy as np
import sympy as sp
from pyquil import Program, get_qc
from pyquil.gates import *
from pyquil.quil import DefGate
from pyquil.paulis import exponentiate
from pyquil.paulis import PauliSum
from pyquil.paulis import PauliTerm
import numpy as np
from scipy import linalg
from numpy.linalg import matrix_power
from pyquil.parameters import Parameter, quil_sin, quil_cos
from pyquil.api import WavefunctionSimulator
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook

# %%
cliffords={0:I,
           1:X,
           2:Y,
           3:Z,
           4:([RX],[-np.pi/2]),
           5:([RX],[np.pi/2]),
           6:([RY],[-np.pi/2]),
           7:([RY],[np.pi/2]),
           8:([RZ],[-np.pi/2]),
           9:([RZ],[np.pi/2]),
           10:([RX,Z],[-np.pi/2,0]),
           11:([RX,Z],[np.pi/2,0]),
           12:([X,RZ],[0,-np.pi/2]),
           13:([X,RZ],[0,(np.pi/2)]),
           14:([RX,RZ],[(np.pi/2),(np.pi/2)]),
           15:([RX,RZ],[(-np.pi/2),(np.pi/2)]),
           16:([RZ,RX],[(-np.pi/2),(np.pi/2)]),
           17:([RY,Z],[(np.pi/2),(0)]),
           18:([RY,RZ],[(-np.pi/2),(np.pi/2)]),
           19:([RY,RZ],[(np.pi/2),(-np.pi/2)]),
           20:H,
           21:([RX,RZ],[(np.pi/2),(-np.pi/2)]),
           22:([RY,RZ],[(np.pi/2),(np.pi/2)]),
           23:([RX,RZ],[(-np.pi/2),(-np.pi/2)]),            
}

# %%
def cliffords_to_program(gate,qubit):     
    prog=[]
    
    if (gate==1 or gate==2 or gate==3 or gate ==0 or gate == 20):
            
        prog.append(cliffords[gate](qubit))

    else :

        for i in range(len(cliffords[gate][0])):
            if (cliffords[gate][1][i]!=0):
                prog.append(cliffords[gate][0][i](cliffords[gate][1][i],qubit))
            else:
                prog.append(cliffords[gate][0][i](qubit))
    
    return prog

# %%
delta =Parameter('delta')

noise_z=np.array([[quil_cos((delta))-1j*quil_sin((delta)),0],
              [0,1j*quil_sin((delta))+quil_cos((delta))]])

noise_z_definition = DefGate('Noise_z', noise_z, [delta])
Noise_z = noise_z_definition.get_constructor()

# %% [markdown]
# # Theoretical

# %%
def generate_sequence_cliffords(length,full_p,indexes,deltas,N_Qubits):    

    full_p+=noise_z_definition
    
    program=[]
    inverse=Program()
    
    for indexx,deltaa in zip(indexes,deltas):
        
        for qubit in range(N_Qubits):
            
            index=indexx[qubit]
            delta=deltaa[qubit]
        
            noise=Noise_z(delta)(qubit)
            program.append(noise)
            program.append(cliffords_to_program(index,qubit))
            inverse+=cliffords_to_program(index,qubit)
        
    full_p+=program 
    full_p+=inverse.dagger()
    
    return full_p

# %%
def write_data(values,path):
    with open(path, 'a') as the_file:
        for value in values:
            the_file.write(str(value)+',')
        the_file.write('\n')

# %% [markdown]
# ## Markovian scenario

# %% [markdown]
# ### Parameters

# %%
sigma_error=0.015
Js=[20,40]
N=50
trials=100
N_Qubitss=[1,2]

path='results/markovianN'+str(N)+'J'+str(Js)+'NQ'+str(N_Qubitss)+'real.txt'

with open(path, 'w') as the_file:
    the_file.write('N='+str(N)+' J = '+str(Js)+' NQ = '+str(N_Qubitss)+' sigma = '+str(sigma_error)+'\n')

# %%
def markovian_theoretical(sigma_error,J,N_Qubits,trials,N,path):
    final=[]    
    for i in tqdm_notebook(range(trials)):
        indexes=np.random.randint(0,24,(J,N_Qubits)) 
        results=[]
        for j in range (N):
            deltas=np.random.normal(0,sigma_error,(J,N_Qubits))
            correction=np.sum(deltas**2)
            p=generate_sequence_cliffords(J,Program(),indexes,deltas,N_Qubits)
            wf_sim = WavefunctionSimulator()
            wavefunction = wf_sim.wavefunction(p)
            results.append(abs(wavefunction[0])**2-(1/3)*correction)
        final.append(np.mean(results))
    write_data(final,path)

# %%
for N_Qubits in N_Qubitss:
    for J in Js: 
        markovian_theoretical(sigma_error,J,N_Qubits,trials,N,path)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))

# %%
results
# Out:
# array([0.98653786, 0.98571226, 0.98651317, 0.98860655, 0.98717644,
#        0.98848137, 0.98595845, 0.98878035, 0.98712222, 0.98531785,
#        0.9887316 , 0.9861715 , 0.98799156, 0.9863142 , 0.9878796 ,
#        0.98505395, 0.9871871 , 0.98678311, 0.98775203, 0.98538158,
#        0.98692064, 0.98676591, 0.98753757, 0.98876779, 0.98693052,
#        0.98783356, 0.98562346, 0.98528114, 0.98601387, 0.9861585 ,
#        0.98622341, 0.98748271, 0.98912747, 0.98723508, 0.98581733,
#        0.98512026, 0.98770357, 0.98794617, 0.98657669, 0.98770771,
#        0.98598021, 0.98773211, 0.98822292, 0.98621912, 0.98777874,
#        0.98625209, 0.9880214 , 0.98730314, 0.98855144, 0.98538978,
#        0.98740538, 0.98467966, 0.98604327, 0.98521013, 0.9862422 ,
#        0.98721058, 0.98497633, 0.98745332, 0.98918079, 0.9885545 ,
#        0.9897878 , 0.98596556, 0.98507122, 0.98668107, 0.98597633,
#        0.98811434, 0.98872535, 0.98693841, 0.98738697, 0.98809749,
#        0.9884012 , 0.98694259, 0.98606354, 0.98676324, 0.98802297,
#        0.98741393, 0.98764336, 0.98801011, 0.98850288, 0.98767951,
#        0.98653427, 0.9870171 , 0.9871039 , 0.98628335, 0.98639652,
#        0.98772781, 0.98763826, 0.98550438, 0.98754706, 0.98616794,
#        0.98631992, 0.98557196, 0.98658809, 0.98964559, 0.98757418,
#        0.98889037, 0.98574801, 0.98602147, 0.98606141, 0.98780635])

# %%
results=np.genfromtxt(path,skip_header=1,delimiter=',')[:,:-1]
plt.hist(results[0],bins=10,density=1)

sigma2=sigma_error**2
alpha=3/2*n
beta=(2/3)*Js[0]*sigma2/n

x=np.linspace(0.8,1,1000)
y = (1-x+(2/3)*Js[0]*sigma2**2)**(alpha-1)*(np.exp(-((1-x+(2/3)*Js[0]*sigma2**2)/beta)))*(beta**(-alpha))/sps.gamma(alpha)
plt.plot(x,y)
plt.xlim(0.9,1)
# Out:
# (0.9, 1)

# %% [markdown]
# ### DC

# %%
sigma_error=0.015
Js=[20,40]
trials=100
N=50
N_Qubitss=[2,3]

740992663907], [-0.01625193149115628], [0.005038388458440699], [0.0003478312792978213], [0.018978143760576452], [-0.008729724566092367], [0.010636791497081712], [-0.01942149125411281], [-0.011625896403965483], [0.012423705536275186], [0.000272785547537799], [-0.00896728994564374], [-0.01130852378969088], [0.01455747414957096], [-0.004558508961507264], [0.0004335453224173385], [-0.009217707049494686], [0.00364765938547459], [-0.0066648658476151385], [0.029296854090152577], [0.0004096197834740826], [-0.00966101455685604], [-0.0009016813122965144], [0.005412744003625337], [0.004016449048871391], [-0.01819711831156969], [0.01584941414904726], [-0.007227528820658116], [0.01187440613586585], [0.010368163067491712], [-0.0027959424957770197], [0.009236931019011746], [0.02795321514747149], [-0.005907727426352684], [-0.001348220771184772], [-0.007568388927336875], [-0.01432252883510802], [-0.008099565139105619], [-0.015793229815601734], [0.03419686032100481], [0.012769240856221538], [-0.028513308291421853], [0.002913184593000767], [0.017010709642304136], [0.042185305171100904], [-0.0222959219044454], [0.022720601007440878], [-0.013044096434583995], [-0.003541955448657012], [0.0086386121256459], [0.01981740992663907], [-0.01625193149115628], [0.005038388458440699], [0.0003478312792978213], [0.018978143760576452], [-0.008729724566092367], [0.010636791497081712], [-0.01942149125411281], [-0.011625896403965483], [0.012423705536275186], [0.000272785547537799], [-0.00896728994564374], [-0.01130852378969088], [0 ...

# %%
for N_Qubits in N_Qubitss:
    for J in Js:
        DC_theoretical(sigma_error,J,N_Qubits,trials,N,path)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))

# %%
results=np.genfromtxt(path,skip_header=1,delimiter=',')[:,:-1]

plt.hist(results[3],bins=40,density=1)

sigma2=sigma_error**2
alpha=1
beta=(2/3)*3*Js[1]*sigma2*(1/2+np.pi*2/96)

x=np.linspace(0.8,1,1000)
y = (1-x)**(alpha-1)*(np.exp(-((1-x)/beta)))*(beta**(-alpha))/sps.gamma(alpha)
plt.plot(x,y)
plt.xlim(0.9,1)
# Out:
# (0.9, 1)

# %% [markdown]
# # 2 Qubits

# %%
theta = Parameter('theta')
delta =Parameter('delta')
u_x=np.array([[quil_cos((theta+delta)/2),1j*quil_sin((theta+delta)/2)],
              [1j*quil_sin((theta+delta)/2),quil_cos((theta+delta)/2)]])

u_z=np.array([[quil_cos((theta+delta)/2)+1j*quil_sin((theta+delta)/2),0],
              [0,-1j*quil_sin((theta+delta)/2)+quil_cos((theta+delta)/2)]])

u_y=np.array([[quil_cos((theta+delta)/2),quil_sin((theta+delta)/2)],
              [-quil_sin((theta+delta)/2),quil_cos((theta+delta)/2)]])

U_x_definition = DefGate('U_x', u_x, [theta,delta])
U_x = U_x_definition.get_constructor()

U_z_definition = DefGate('U_z', u_z, [theta,delta])
U_z = U_z_definition.get_constructor()

U_y_definition = DefGate('U_y', u_y, [theta,delta])
U_y = U_y_definition.get_constructor()

# %%
#Defining again, but with sign change to match the other operators
cliffords_2={0:I,
           1:X,
           2:Y,
           3:Z,
           4:([RX],[-np.pi/2]),
           5:([RX],[np.pi/2]),
           6:([RY],[-np.pi/2]),
           7:([RY],[np.pi/2]),
           8:([RZ],[-np.pi/2]),
           9:([RZ],[np.pi/2]),
           10:([RX,Z],[-np.pi/2,0]),
           11:([RX,Z],[np.pi/2,0]),
           12:([X,RZ],[0,-np.pi/2]),
           13:([X,RZ],[0,(np.pi/2)]),
           14:([RX,RZ],[(-np.pi/2),(-np.pi/2)]),
           15:([RX,RZ],[(np.pi/2),(-np.pi/2)]),
           16:([RZ,RX],[(np.pi/2),(-np.pi/2)]),
           17:([RY,Z],[(np.pi/2),(0)]),
           18:([RY,RZ],[(np.pi/2),(-np.pi/2)]),
           19:([RY,RZ],[(-np.pi/2),(np.pi/2)]),
           20:H,
           21:([RX,RZ],[(-np.pi/2),(np.pi/2)]),
           22:([RY,RZ],[(-np.pi/2),(-np.pi/2)]),
           23:([RX,RZ],[(np.pi/2),(np.pi/2)]),            
}

# %%
generators={   
    #X
    1:([U_z,U_x,U_z,U_x],[-np.pi,-np.pi/2,np.pi,np.pi/2]),
    #Y
    2:([U_z,U_y,U_z,U_y],[-np.pi,-np.pi/2,np.pi,np.pi/2]),
    #Z
    3:([U_z],[np.pi]),
    #Rx+
    4:([U_z,U_x,U_z,U_x],[-np.pi,-np.pi/4,np.pi,np.pi/4]),
    #Rx-
    5:([U_z,U_x,U_z,U_x],[-np.pi,np.pi/4,np.pi,-np.pi/4]),
    #Ry+
    6:([U_z,U_y,U_z,U_y],[-np.pi,-np.pi/4,np.pi,np.pi/4]),
    #Ry-
    7:([U_z,U_y,U_z,U_y],[-np.pi,np.pi/4,np.pi,-np.pi/4]),
    #Rz+
    8:([U_z],[np.pi/2]),
    #Rz-
    9:([U_z],[-np.pi/2])   
}

compilation={
    0:(generators[3][0]+generators[3][0],generators[3][1]+generators[3][1]),
    1:generators[1],
    2:generators[2],
    3:generators[3],
    4:generators[4],
    5:generators[5],
    6:generators[6],
    7:generators[7],
    8:generators[8],
    9:generators[9],
    #ZRx+
    10:(generators[3][0]+generators[4][0],generators[3][1]+generators[4][1]),
    #ZRx-
    11:(generators[3][0]+generators[5][0],generators[3][1]+generators[5][1]),
    #Rz+X
    12:(generators[8][0]+generators[1][0],generators[8][1]+generators[1][1]),
    #Rz-X
    13:(generators[9][0]+generators[1][0],generators[9][1]+generators[1][1]),
    #Rz+X
    14:(generators[8][0]+generators[4][0],generators[8][1]+generators[4][1]),
    15:(generators[8][0]+generators[5][0],generators[8][1]+generators[5][1]),
    
    16:(generators[4][0]+generators[9][0],generators[4][1]+generators[9][1]),
    
    17:(generators[3][0]+generators[7][0],generators[3][1]+generators[7][1]),
    
    18:(generators[8][0]+generators[7][0],generators[8][1]+generators[7][1]),
    
    19:(generators[9][0]+generators[6][0],generators[9][1]+generators[6][1]),
    
    20:(generators[3][0]+generators[6][0],generators[3][1]+generators[6][1]),
    
    21:(generators[9][0]+generators[4][0],generators[9][1]+generators[4][1]),
    
    22:(generators[8][0]+generators[6][0],generators[8][1]+generators[6][1]),
    
    23:(generators[9][0]+generators[5][0],generators[9][1]+generators[5][1])
}

# %%
def inverse(list_c):
    
    prog=[]
    
    for element in list_c:
        
        gate=element[0]
        qubit=element[1]
        
        if (gate==1 or gate==2 or gate==3 or gate ==0 or gate == 20):
            
            prog.append(cliffords_2[gate](qubit))
        
        else :
            
            for i in range(len(cliffords_2[gate][0])):
                if (cliffords_2[gate][1][i]!=0):
                    prog.append(cliffords_2[gate][0][i](cliffords_2[gate][1][i],qubit))
                else:
                    prog.append(cliffords_2[gate][0][i](qubit))
    return prog

# %%
def compilation_to_program(N,clifford,qubit,noise=0): 
    prog=[]
    
    gates=compilation[clifford]

    for i in range(len(gates[0])):

        gate=gates[0][i]
        angle=gates[1][i]            

        if(gate==U_z):

            prog.append(gate(angle,noise)(qubit))

        else:
            for j in range(N):              
                prog.append(gate(angle,noise)(j))
         
    return prog[::-1]

# %%
def generate_sequence(length,full_p,N,indexes,deltas,N_Qubits):

    program=[]
    inverseP=Program()
    
    aux_inverse=[]
    
    for indexx,deltaa in zip(indexes,deltas):
        for qubit in range(N_Qubits):
            
            index=indexx[qubit]
            delta=deltaa[qubit]
            gate=compilation_to_program(N,index,qubit,noise=delta)
            aux_inverse.append((index,qubit))
            program.append(gate)

                   
    inverseP+=inverse(aux_inverse)
    full_p+=program 
    full_p+=inverseP.dagger()
    
    
    return full_p

# %% [markdown]
# ## Markov

# %%
def markov_real(sigma_error,J,N_Qubits,trials,N,path):
    final=[]
    for i in tqdm_notebook(range(trials)):
        indexes=np.random.randint(0,24,(J,N_Qubits)) 
        results=[]
        for j in range (N):
            p = Program()
            p+=U_x_definition
            p+=U_y_definition
            p+=U_z_definition
            deltas=np.random.normal(0,sigma_error,(J,N_Qubits))
            correction=np.sum(deltas**2)
            p=generate_sequence(J,p,N_Qubits,indexes,deltas,N_Qubits)    
            wf_sim = WavefunctionSimulator()
            wavefunction = wf_sim.wavefunction(p)
            results.append(abs(wavefunction[0])**2-(1/3)*correction)
        final.append(np.mean(results))
    write_data(final,path)

# %%
sigma_error=0.015
Js=[20,30]
N_Qubitss=[2,3]
trials=100
N=50
timestr = time.strftime("%m%d-%H%M%S")
path='results/markovianITNQ'+str(N_Qubitss)+'-'+timestr+".txt"

with open(path, 'w') as the_file:
    the_file.write('Iont Trap N='+str(N)+' J = '+str(Js)+' NQ = '+str(N_Qubitss)+' sigma = '+str(sigma_error)+'\n')

# %%
for N_Qubits in N_Qubitss:
    for J in Js:
        markov_real(sigma_error,J,N_Qubits,trials,N,path)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))

# %%
results=np.genfromtxt(path,skip_header=1,delimiter=',')[:,:-1]
plt.hist(results[3],bins=20,density=1)
J=Js[0]
sigma2=sigma_error**2
alpha=3/2*n
beta=(2/3)*2*J*sigma2/n

x=np.linspace(0.8,1,1000)
y = (1-x+(2/3)*J*sigma2**2)**(alpha-1)*(np.exp(-((1-x+(2/3)*J*sigma2**2)/beta)))*(beta**(-alpha))/sps.gamma(alpha)
plt.plot(x,y)
plt.xlim(0.9,1)
# Out:
# (0.9, 1)

# %%
# Out:
# [1, 2]

# %%
sigma_error=0.015
Js=[40]
N_Qubitss=[2]
trials=100
N=50
path='results/DCITN'+str(N)+'J'+str(Js)+'NQ'+str(N_Qubitss)+'.txt'

with open(path, 'w') as the_file:
    the_file.write('Iont Trap N='+str(N)+' J = '+str(Js)+' NQ = '+str(N_Qubitss)+' sigma = '+str(sigma_error)+'\n')

# %%
def DC_real(sigma_error,J,N_Qubits,trials,N,path):
    final=[]
    for i in tqdm_notebook(range(trials)):
        indexes=np.random.randint(0,24,(J,N_Qubits)) 
        results=[]
        for j in range (N):
            p = Program()
            p+=U_x_definition
            p+=U_y_definition
            p+=U_z_definition
            deltas=[[np.random.normal(0,sigma_error)]*N_Qubits]*J
            correction=N_Qubits*J*deltas[0][0]**2
            p=generate_sequence(J,p,N_Qubits,indexes,deltas,N_Qubits)
            wf_sim = WavefunctionSimulator()
            wavefunction = wf_sim.wavefunction(p)
            results.append(abs(wavefunction[0])**2-(1/3)*correction)
        final.append(np.mean(results))
    write_data(final,path)

# %%
for N_Qubits in N_Qubitss:
    for J in Js:
        DC_real(sigma_error,J,N_Qubits,trials,N,path)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))

# %%
results=np.genfromtxt(path,skip_header=1,delimiter=',')[:-1]
plt.hist(results,bins=20,density=1)

sigma2=sigma_error**2
alpha=3/2
beta=(2/3)*8*J*sigma2*(1/2+np.pi*2/96)

x=np.linspace(0.8,1,1000)
y = (1-x)**(alpha-1)*(np.exp(-((1-x)/beta)))*(beta**(-alpha))/sps.gamma(alpha)
plt.plot(x,y)
plt.xlim(0.9,1)
# Out:
# (0.9, 1)

# %%
plt.plot(np.mean(results,axis=1)[:4],"o")

# %%
plt.hist(results[2],bins=100)
# Out:
# (array([  2.,   0.,   1.,   0.,   1.,   3.,   4.,   2.,   1.,   2.,   0.,
#           0.,   2.,   3.,   2.,   2.,   1.,   1.,   1.,   1.,   1.,   2.,
#           3.,   1.,   1.,   1.,   6.,   2.,   1.,   0.,   0.,   2.,   1.,
#           2.,   2.,   1.,   3.,   4.,   3.,   3.,   5.,   2.,   6.,  12.,
#           3.,   1.,   2.,  10.,   7.,   1.,   6.,   3.,   5.,   3.,   8.,
#           2.,   4.,   3.,   2.,   8.,   2.,   5.,   5.,   3.,   6.,   3.,
#           4.,   2.,   5.,   5.,   7.,  11.,  12.,  10.,   9.,  10.,   6.,
#          11.,   8.,   9.,   9.,  10.,   9.,   6.,  20.,  20.,  14.,  17.,
#          15.,  17.,  20.,  26.,  20.,  36.,  29.,  34.,  43.,  56.,  76.,
#         229.]),
#  array([-9.9290e-01, -9.8297e-01, -9.7304e-01, -9.6311e-01, -9.5318e-01,
#         -9.4325e-01, -9.3332e-01, -9.2339e-01, -9.1346e-01, -9.0353e-01,
#         -8.9360e-01, -8.8367e-01, -8.7374e-01, -8.6381e-01, -8.5388e-01,
#         -8.4395e-01, -8.3402e-01, -8.2409e-01, -8.1416e-01, -8.0423e-01,
#         -7.9430e-01, -7.8437e-01, -7.7444e-01, -7.6451e-01, -7.5458e-01,
#         -7.4465e-01, -7.3472e-01, -7.2479e-01, -7.1486e-01, -7.0493e-01,
#         -6.9500e-01, -6.8507e-01, -6.7514e-01, -6.6521e-01, -6.5528e-01,
#         -6.4535e-01, -6.3542e-01, -6.2549e-01, -6.1556e-01, -6.0563e-01,
#         -5.9570e-01, -5.8577e-01, -5.7584e-01, -5.6591e-01, -5.5598e-01,
#         -5.4605e-01, -5.3612e-01, -5.2619e-01, -5.1626e-01, -5.0633e-01,
#         -4.9640e-01, -4.8647e-01, -4.7654e-01, -4.6661e-01, -4.5668e-01,
#         -4.4675e-01, -4.3682e-01, -4.2689e-01, -4.1696e-01, -4.0703e-01,
#         -3.9710e-01, -3.8717e-01, -3.7724e-01, -3.6731e-01, -3.5738e-01,
#         -3.4745e-01, -3.3752e-01, -3.2759e-01, -3.1766e-01, -3.0773e-01,
#         -2.9780e-01, -2.8787e-01, -2.7794e-01, -2.6801e-01, -2.5808e-01,
#         -2.4815e-01, -2.3822e-01, -2.2829e-01, -2.1836e-01, -2.0843e-01,
#         -1.9850e-01, -1.8857e-01, -1.7864e-01, -1.6871e-01, -1.5878e-01,
#         -1.4885e-01, -1.3892e-01, -1.2899e-01, -1.1906e-01, -1.0913e-01,
#         -9.9200e-02, -8.9270e-02, -7.9340e-02, -6.9410e-02, -5.9480e-02,
#         -4.9550e-02, -3.9620e-02, -2.9690e-02, -1.9760e-02, -9.8300e-03,
#          1.0000e-04]),
#  <a list of 100 Patch objects>)

# %%
J=500
n=1
sigma2=0.015
alpha=3/2*70
beta=(2/3)*J*sigma2**2/70

x=np.linspace(0,1,1000)

import scipy.special as sps
y = (1-x)**(alpha-1)*(np.exp(-((1-x)/beta)))*(beta**(-alpha))/sps.gamma(alpha)

plt.plot(x,y)
plt.xlim(0.8,1)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-156-772de0adde3e> in <module>
#       8
#       9 import scipy.special as sps
# ---> 10 y = (1-x)**(alpha-1)*(np.exp(-((1-x)/beta)))*(beta**(-alpha))/sps.gamma(alpha)
#      11
#      12 plt.plot(x,y)
#
# OverflowError: (34, 'Result too large')

# %%
J=100
n=1
sigma2=0.015
alpha=3/2
beta=(2/3)*J*sigma2

s = np.random.gamma(alpha,1/beta, 10000)

count, bins, ignored = plt.hist(s, 500, density=True)

plt.xlim(0,0.1)
# Out:
# (0, 0.1)

# %%
final_x=[]
for i in range (10):
    
    temp=[lengths[i]]
    temp*=100
    
    final_x+=temp

results.reshape(9*sub_trials)

means=np.mean(results,axis=1)
standards=np.std(results,axis=1)

# %%
plt.plot(final_x[0:-100],1-results.reshape(9*sub_trials),"o",ms=1)
plt.plot(lengths,1-means,"o--",ms=1)
plt.errorbar(lengths, 1-means, yerr=standards/np.sqrt(100))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-521-9c49d25a267e> in <module>
#       1 plt.plot(final_x[0:-100],1-results.reshape(9*sub_trials),"o",ms=1)
# ----> 2 plt.plot(lengths,1-means,"o--",ms=1)
#       3 plt.errorbar(lengths, 1-means, yerr=standards/np.sqrt(100))
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     229         if x.shape[0] != y.shape[0]:
#     230             raise ValueError("x and y must have same first dimension, but "
# --> 231                              "have shapes {} and {}".format(x.shape, y.shape))
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (11,) and (9,)

# %%
X
# Out:
# <function pyquil.gates.X(qubit)>

# %%
p = Program()
p+=U_x_definition
p+=U_y_definition
p+=U_z_definition
p=generate_sequence(1000,p,0,3,0)
wf_sim = WavefunctionSimulator()
wavefunction = wf_sim.wavefunction(p)
# Out:
# [(23, 0), (1, 1), (23, 2), (18, 0), (0, 1), (14, 2), (21, 0), (16, 1), (8, 2), (0, 0), (1, 1), (20, 2), (23, 0), (5, 1), (23, 2), (20, 0), (4, 1), (16, 2), (11, 0), (21, 1), (3, 2), (12, 0), (9, 1), (3, 2), (3, 0), (20, 1), (22, 2), (7, 0), (2, 1), (11, 2), (9, 0), (15, 1), (4, 2), (23, 0), (17, 1), (14, 2), (6, 0), (17, 1), (23, 2), (14, 0), (21, 1), (19, 2), (4, 0), (12, 1), (1, 2), (5, 0), (5, 1), (16, 2), (3, 0), (18, 1), (20, 2), (2, 0), (16, 1), (18, 2), (18, 0), (15, 1), (5, 2), (16, 0), (7, 1), (20, 2), (5, 0), (16, 1), (12, 2), (13, 0), (4, 1), (8, 2), (16, 0), (16, 1), (2, 2), (23, 0), (16, 1), (2, 2), (15, 0), (7, 1), (18, 2), (6, 0), (18, 1), (19, 2), (18, 0), (19, 1), (0, 2), (9, 0), (9, 1), (11, 2), (7, 0), (1, 1), (11, 2), (8, 0), (9, 1), (11, 2), (6, 0), (16, 1), (8, 2), (10, 0), (5, 1), (11, 2), (15, 0), (16, 1), (18, 2), (13, 0), (19, 1), (6, 2), (4, 0), (13, 1), (12, 2), (19, 0), (23, 1), (5, 2), (3, 0), (13, 1), (8, 2), (2, 0), (22, 1), (1, 2), (7, 0), (23, 1), (16, 2), (16, 0), (16, 1), (7, 2), (1, 0), (9, 1), (16, 2
 0), (16, 1), (6, 2), (16, 0), (15, 1), (15, 2), (22, 0), (19, 1), (5, 2), (4, 0), (4, 1), (16, 2), (17, 0), (15, 1), (10, 2), (21, 0), (20, 1), (3, 2), (19, 0), (5, 1), (1, 2), (16, 0), (0, 1), (11, 2), (7, 0), (3, 1), (17, 2), (12, 0), (11, 1), (5, 2), (13, 0), (13, 1), (8, 2), (1, 0), (13, 1), (16, 2), (23, 0), (7, 1), (2, 2), (14, 0), (16, 1), (22, 2), (12, 0), (7, 1), (9, 2), (14, 0), (11, 1), (20, 2), (13, 0), (15, 1), (3, 2), (18, 0), (18, 1), (18, 2), (5, 0), (21, 1), (3, 2), (3, 0), (16, 1), (22, 2), (1, 0), (23, 1), (11, 2), (16, 0), (12, 1), (14, 2), (8, 0), (16, 1), (2, 2), (5, 0), (9, 1), (4, 2), (15, 0), (22, 1), (2, 2), (0, 0), (0, 1), (20, 2), (12, 0), (13, 1), (18, 2), (12, 0), (1, 1), (4, 2), (6, 0), (12, 1), (2, 2), (15, 0), (12, 1), ...
# DEFGATE U_x(%theta, %delta):
#     COS((%theta + %delta)/2), i*SIN((%theta + %delta)/2)
#     i*SIN((%theta + %delta)/2), COS((%theta + %delta)/2)
#
# DEFGATE U_y(%theta, %delta):
#     COS((%theta + %delta)/2), SIN((%theta + %delta)/2)
#     -1*SIN((%theta + %delta)/2), COS((%theta + %delta)/2)
#
# DEFGATE U_z(%theta, %delta):
#     COS((%theta + %delta)/2) + i*SIN((%theta + %delta)/2), 0
#     0, -i*SIN((%theta + %delta)/2) + COS((%theta + %delta)/2)
#
# I 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 0
# U_z(-pi/2,0) 0
# I 1
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 1
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 1
# I 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 2
# U_z(-pi/2,0) 2
# I 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_z(pi,0) 1
# U_z(pi,0) 1
# I 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi/2,0) 2
# I 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# U_z(-pi/2,0) 0
# I 1
# U_z(-pi/2,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_z(pi/2,0) 2
# I 0
# U_z(pi,0) 0
# U_z(pi,0) 0
# I 1
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 1
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi,0) 2
# I 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi/2,0) 2
# I 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi,0) 1
# I 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 2
# U_z(-pi/2,0) 2
# I 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(-pi/2,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# U_z(-pi/2,0) 2
# I 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 1
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 1
# U_z(pi/2,0) 1
# I 2
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 2
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 2
# I 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_z(-pi/2,0) 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 2
# I 0
# U_z(pi,0) 0
# I 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi/2,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi,0) 2
# I 0
# U_y(pi/2,0) 2
# U_y(pi/2,0) 1
# U_y(pi/2,0) 0
# U_z(pi,0) 0
# U_y(-pi/2,0) 2
# U_y(-pi/2,0) 1
# U_y(-pi/2,0) 0
# U_z(-pi,0) 0
# I 1
# U_z(-pi/2,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi/2,0) 2
# I 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi/2,0) 1
# I 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 2
# I 0
# U_z(-pi/2,0) 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi,0) 2
# I 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_z(-pi/2,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 2
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 2
# U_z(pi/2,0) 2
# I 0
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 0
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 0
# U_z(-pi/2,0) 0
# I 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_z(pi/2,0) 2
# I 0
# U_z(-pi/2,0) 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_z(-pi/2,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_y(pi/2,0) 2
# U_y(pi/2,0) 1
# U_y(pi/2,0) 0
# U_z(pi,0) 2
# U_y(-pi/2,0) 2
# U_y(-pi/2,0) 1
# U_y(-pi/2,0) 0
# U_z(-pi,0) 2
# I 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 0
# U_z(-pi/2,0) 0
# I 1
# U_z(-pi/2,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_y(pi/2,0) 2
# U_y(pi/2,0) 1
# U_y(pi/2,0) 0
# U_z(pi,0) 2
# U_y(-pi/2,0) 2
# U_y(-pi/2,0) 1
# U_y(-pi/2,0) 0
# U_z(-pi,0) 2
# I 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi/2,0) 2
# I 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi/2,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# U_z(-pi/2,0) 2
# I 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(-pi/2,0) 1
# I 2
# U_z(pi,0) 2
# U_z(pi,0) 2
# I 0
# U_z(-pi/2,0) 0
# I 1
# U_z(-pi/2,0) 1
# I 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi,0) 2
# I 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 1
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 1
# I 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi,0) 2
# I 0
# U_z(pi/2,0) 0
# I 1
# U_z(-pi/2,0) 1
# I 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi,0) 2
# I 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_z(-pi/2,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_z(pi/2,0) 2
# I 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi,0) 0
# I 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi,0) 2
# I 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_z(-pi/2,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi/2,0) 2
# I 0
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 0
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 0
# U_z(-pi/2,0) 0
# I 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(-pi/2,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# I 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 1
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 1
# U_z(-pi/2,0) 1
# I 2
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 2
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 2
# U_z(pi/2,0) 2
# I 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 0
# U_z(-pi/2,0) 0
# I 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 1
# U_z(-pi/2,0) 1
# I 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 2
# I 0
# U_z(pi,0) 0
# I 1
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 1
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 1
# U_z(-pi/2,0) 1
# I 2
# U_z(pi/2,0) 2
# I 0
# U_y(pi/2,0) 2
# U_y(pi/2,0) 1
# U_y(pi/2,0) 0
# U_z(pi,0) 0
# U_y(-pi/2,0) 2
# U_y(-pi/2,0) 1
# U_y(-pi/2,0) 0
# U_z(-pi,0) 0
# I 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi/2,0) 1
# I 2
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 2
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 2
# I 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 1
# U_z(-pi/2,0) 1
# I 2
# U_z(-pi/2,0) 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 2
# I 0
# U_z(-pi/2,0) 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_z(-pi/2,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 2
# I 0
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 0
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 0
# I 1
# U_z(-pi/2,0) 1
# I 2
# U_z(-pi/2,0) 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 2
# I 0
# U_z(pi/2,0) 0
# I 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_z(pi,0) 2
# U_z(pi,0) 2
# I 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi,0) 1
# I 2
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 2
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 2
# U_z(pi/2,0) 2
# I 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# U_z(-pi/2,0) 0
# I 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi,0) 1
# I 2
# U_z(pi,0) 2
# U_z(pi,0) 2
# I 0
# U_y(pi/2,0) 2
# U_y(pi/2,0) 1
# U_y(pi/2,0) 0
# U_z(pi,0) 0
# U_y(-pi/2,0) 2
# U_y(-pi/2,0) 1
# U_y(-pi/2,0) 0
# U_z(-pi,0) 0
# I 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi/2,0) 2
# I 0
# U_z(-pi/2,0) 0
# I 1
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 1
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 1
# U_z(-pi/2,0) 1
# I 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 2
# I 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_z(-pi/2,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# I 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(-pi/2,0) 1
# I 2
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 2
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 2
# I 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi,0) 1
# I 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 2
# U_z(-pi/2,0) 2
# I 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi,0) 0
# I 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 2
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 2
# U_z(-pi/2,0) 2
# I 0
# U_y(pi/2,0) 2
# U_y(pi/2,0) 1
# U_y(pi/2,0) 0
# U_z(pi,0) 0
# U_y(-pi/2,0) 2
# U_y(-pi/2,0) 1
# U_y(-pi/2,0) 0
# U_z(-pi,0) 0
# I 1
# U_z(-pi/2,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi/2,0) 2
# I 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi,0) 0
# I 1
# U_z(pi,0) 1
# I 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_z(-pi/2,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_z(pi/2,0) 2
# I 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi/2,0) 1
# I 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 2
# U_z(-pi/2,0) 2
# I 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_y(pi/2,0) 2
# U_y(pi/2,0) 1
# U_y(pi/2,0) 0
# U_z(pi,0) 1
# U_y(-pi/2,0) 2
# U_y(-pi/2,0) 1
# U_y(-pi/2,0) 0
# U_z(-pi,0) 1
# I 2
# U_z(-pi/2,0) 2
# I 0
# U_z(pi,0) 0
# I 1
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 1
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 1
# U_z(-pi/2,0) 1
# I 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 2
# U_z(-pi/2,0) 2
# I 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 0
# U_z(-pi/2,0) 0
# I 1
# U_z(-pi/2,0) 1
# I 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 2
# I 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_z(pi,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# U_z(-pi/2,0) 2
# I 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi,0) 0
# I 1
# U_z(pi,0) 1
# I 2
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 2
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 2
# U_z(pi/2,0) 2
# I 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi/2,0) 1
# I 2
# U_z(-pi/2,0) 2
# I 0
# U_y(pi/2,0) 2
# U_y(pi/2,0) 1
# U_y(pi/2,0) 0
# U_z(pi,0) 0
# U_y(-pi/2,0) 2
# U_y(-pi/2,0) 1
# U_y(-pi/2,0) 0
# U_z(-pi,0) 0
# I 1
# U_z(-pi/2,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# I 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_z(pi,0) 1
# U_z(pi,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi,0) 2
# I 0
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 0
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 0
# I 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi,0) 1
# I 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 2
# I 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi/2,0) 1
# I 2
# U_z(pi/2,0) 2
# I 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_y(pi/2,0) 2
# U_y(pi/2,0) 1
# U_y(pi/2,0) 0
# U_z(pi,0) 1
# U_y(-pi/2,0) 2
# U_y(-pi/2,0) 1
# U_y(-pi/2,0) 0
# U_z(-pi,0) 1
# I 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi/2,0) 2
# I 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_z(-pi/2,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi/2,0) 2
# I 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 1
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 1
# U_z(pi/2,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# U_z(-pi/2,0) 2
# I 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 0
# U_z(-pi/2,0) 0
# I 1
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 1
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 1
# I 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi,0) 2
# I 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 1
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 1
# U_z(-pi/2,0) 1
# I 2
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 2
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 2
# U_z(-pi/2,0) 2
# I 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi/2,0) 1
# I 2
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 2
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 2
# U_z(-pi/2,0) 2
# I 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi,0) 0
# I 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(-pi/2,0) 1
# I 2
# U_z(pi,0) 2
# U_z(pi,0) 2
# I 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi/2,0) 1
# I 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi,0) 2
# I 0
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 0
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 0
# I 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi,0) 1
# I 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi/2,0) 2
# I 0
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 0
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi,0) 1
# I 2
# U_y(pi/2,0) 2
# U_y(pi/2,0) 1
# U_y(pi/2,0) 0
# U_z(pi,0) 2
# U_y(-pi/2,0) 2
# U_y(-pi/2,0) 1
# U_y(-pi/2,0) 0
# U_z(-pi,0) 2
# I 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 0
# U_z(-pi/2,0) 0
# I 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi/2,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# U_z(-pi/2,0) 2
# I 0
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 0
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 0
# I 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi/2,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# I 0
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 0
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi,0) 1
# I 2
# U_z(pi/2,0) 2
# I 0
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 0
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 0
# I 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 1
# U_z(-pi/2,0) 1
# I 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 2
# U_z(-pi/2,0) 2
# I 0
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 0
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi/2,0) 1
# I 2
# U_z(-pi/2,0) 2
# I 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi,0) 0
# I 1
# U_z(pi,0) 1
# I 2
# U_y(pi/2,0) 2
# U_y(pi/2,0) 1
# U_y(pi/2,0) 0
# U_z(pi,0) 2
# U_y(-pi/2,0) 2
# U_y(-pi/2,0) 1
# U_y(-pi/2,0) 0
# U_z(-pi,0) 2
# I 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 0
# U_z(-pi/2,0) 0
# I 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# I 0
# U_z(-pi/2,0) 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi,0) 1
# I 2
# U_y(pi/2,0) 2
# U_y(pi/2,0) 1
# U_y(pi/2,0) 0
# U_z(pi,0) 2
# U_y(-pi/2,0) 2
# U_y(-pi/2,0) 1
# U_y(-pi/2,0) 0
# U_z(-pi,0) 2
# I 0
# U_z(pi/2,0) 0
# I 1
# U_z(-pi/2,0) 1
# I 2
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 2
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 2
# U_z(pi/2,0) 2
# I 0
# U_z(pi,0) 0
# I 1
# U_z(pi/2,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# U_z(-pi/2,0) 2
# I 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi,0) 0
# I 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi/2,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# U_z(-pi/2,0) 2
# I 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(-pi/2,0) 1
# I 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 2
# U_z(-pi/2,0) 2
# I 0
# U_z(pi,0) 0
# I 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi,0) 1
# I 2
# U_z(pi,0) 2
# I 0
# U_z(-pi/2,0) 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_z(-pi/2,0) 1
# I 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi,0) 2
# I 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_z(-pi/2,0) 1
# I 2
# U_z(pi,0) 2
# U_z(pi,0) 2
# I 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi,0) 1
# I 2
# U_z(pi/2,0) 2
# I 0
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 0
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi,0) 2
# I 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi/2,0) 1
# I 2
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 2
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 2
# I 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_y(pi/2,0) 2
# U_y(pi/2,0) 1
# U_y(pi/2,0) 0
# U_z(pi,0) 1
# U_y(-pi/2,0) 2
# U_y(-pi/2,0) 1
# U_y(-pi/2,0) 0
# U_z(-pi,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# I 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# I 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# U_z(-pi/2,0) 0
# I 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi,0) 1
# I 2
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 2
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 2
# U_z(pi/2,0) 2
# I 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 0
# U_z(-pi/2,0) 0
# I 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# I 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# U_z(-pi/2,0) 2
# I 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi,0) 0
# I 1
# U_z(pi/2,0) 1
# I 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi/2,0) 2
# I 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_z(pi/2,0) 1
# I 2
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 2
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 2
# I 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi,0) 0
# I 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi/2,0) 2
# I 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi/2,0) 0
# I 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(-pi/2,0) 1
# I 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 2
# I 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_z(-pi/2,0) 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 2
# I 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(pi,0) 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(-pi,0) 0
# U_z(pi,0) 0
# I 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi/2,0) 1
# I 2
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 2
# U_z(pi,0) 2
# I 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# U_z(-pi/2,0) 0
# I 1
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 1
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 1
# U_z(pi,0) 1
# I 2
# U_z(pi,0) 2
# I 0
# U_y(pi/4,0) 2
# U_y(pi/4,0) 1
# U_y(pi/4,0) 0
# U_z(pi,0) 0
# U_y(-pi/4,0) 2
# U_y(-pi/4,0) 1
# U_y(-pi/4,0) 0
# U_z(-pi,0) 0
# U_z(-pi/2,0) 0
# I 1
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 1
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(-pi,0) 1
# I 2
# U_x(pi/2,0) 2
# U_x(pi/2,0) 1
# U_x(pi/2,0) 0
# U_z(pi,0) 2
# U_x(-pi/2,0) 2
# U_x(-pi/2,0) 1
# U_x(-pi/2,0) 0
# U_z(-pi,0) 2
# I 0
# U_z(-pi/2,0) 0
# U_x(pi/4,0) 2
# U_x(pi/4,0) 1
# U_x(pi/4,0) 0
# U_z(pi,0) 0
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(-pi,0) 0
# I 1
# U_z(pi,0) 1
# U_z(pi,0) 1
# I 2
# U_x(-pi/4,0) 2
# U_x(-pi/4,0) 1
# U_x(-pi/4,0) 0
# U_z(pi,0) 2
# U_x(pi/4,0) 2
# ...
# Z 2
# RZ(pi/2) 1
# RY(-pi/2) 1
# RY(-pi/2) 0
# RY(-pi/2) 2
# RY(pi/2) 1
# Z 0
# RX(pi/2) 0
# RX(-pi/2) 2
# Z 1
# RX(pi/2) 1
# RZ(pi/2) 0
# RX(-pi/2) 0
# Y 2
# RZ(-pi/2) 1
# RY(pi/2) 1
# RZ(pi/2) 0
# RX(pi/2) 0
# RY(-pi/2) 2
# RY(-pi/2) 1
# RZ(-pi/2) 0
# RX(-pi/2) 0
# X 2
# Z 1
# RX(-pi/2) 1
# RZ(pi/2) 0
# RY(pi/2) 0
# H 2
# Z 1
# RX(pi/2) 1
# Z 0
# RZ(pi/2) 2
# RZ(-pi/2) 1
# RZ(-pi/2) 0
# RX(-pi/2) 0
# Y 2
# RX(pi/2) 1
# RZ(-pi/2) 1
# RX(pi/2) 0
# RZ(-pi/2) 0
# RZ(pi/2) 2
# RX(pi/2) 1
# RZ(-pi/2) 0
# X 0
# RZ(pi/2) 2
# X 2
# RX(pi/2) 1
# RZ(-pi/2) 1
# RX(-pi/2) 0
# H 2
# RY(-pi/2) 1
# RX(pi/2) 0
# RZ(-pi/2) 0
# RX(-pi/2) 2
# RZ(pi/2) 1
# RX(-pi/2) 1
# RZ(pi/2) 0
# RY(-pi/2) 0
# RZ(pi/2) 2
# RY(-pi/2) 2
# RX(pi/2) 1
# RZ(-pi/2) 1
# Y 0
# H 2
# RZ(pi/2) 1
# RY(-pi/2) 1
# Z 0
# RX(pi/2) 2
# RZ(-pi/2) 2
# RX(-pi/2) 1
# RX(-pi/2) 0
# X 2
# RZ(pi/2) 1
# X 1
# RX(pi/2) 0
# RZ(-pi/2) 2
# RY(pi/2) 2
# RZ(-pi/2) 1
# RX(pi/2) 1
# RZ(pi/2) 0
# RX(pi/2) 0
# RZ(-pi/2) 2
# RX(-pi/2) 2
# Z 1
# RY(-pi/2) 1
# RY(pi/2) 0
# RZ(pi/2) 2
# RX(pi/2) 2
# Z 1
# RY(-pi/2) 1
# RZ(-pi/2) 0
# RX(-pi/2) 0
# RX(pi/2) 2
# RZ(pi/2) 1
# RX(-pi/2) 1
# RZ(-pi/2) 0
# Z 2
# RX(-pi/2) 2
# Y 1
# RY(-pi/2) 0
# RZ(pi/2) 2
# RY(pi/2) 2
# H 1
# Z 0
# Z 2
# RZ(-pi/2) 1
# RZ(pi/2) 0
# X 0
# Z 2
# RZ(-pi/2) 1
# RX(pi/2) 1
# Z 0
# RX(-pi/2) 0
# RX(pi/2) 2
# RZ(-pi/2) 2
# RX(pi/2) 1
# H 0
# RZ(-pi/2) 2
# RX(-pi/2) 2
# RX(-pi/2) 1
# RZ(-pi/2) 0
# RX(-pi/2) 0
# H 2
# X 1
# I 0
# RZ(pi/2) 2
# RX(pi/2) 1
# RZ(-pi/2) 1
# RZ(-pi/2) 0
# RX(pi/2) 0
# RZ(pi/2) 2
# RX(pi/2) 2
# I 1
# RZ(pi/2) 0
# RY(-pi/2) 0
# RZ(-pi/2) 2
# RX(-pi/2) 2
# X 1
# RZ(-pi/2) 0
# RX(-pi/2) 0

# %%
print(wavefunction)
# Out:
# (-0-1j)|000>

# %%
inverse([(1, 0), (12, 1)])
# Out:
# [<Gate X 0>, <Gate X 1>, <Gate RZ(-pi/2) 1>]

# %%
p=Program()
p+=U_x_definition
p+=U_y_definition
p+=U_z_definition
p=generate_sequence(1,p,0,2,0.1)

# %%
print(p)
# Out:
# DEFGATE U_x(%theta, %delta):
#     COS((%theta + %delta)/2), i*SIN((%theta + %delta)/2)
#     i*SIN((%theta + %delta)/2), COS((%theta + %delta)/2)
#
# DEFGATE U_y(%theta, %delta):
#     COS((%theta + %delta)/2), SIN((%theta + %delta)/2)
#     -1*SIN((%theta + %delta)/2), COS((%theta + %delta)/2)
#
# DEFGATE U_z(%theta, %delta):
#     COS((%theta + %delta)/2) + i*SIN((%theta + %delta)/2), 0
#     0, -i*SIN((%theta + %delta)/2) + COS((%theta + %delta)/2)
#
# I 0
# U_x(pi/4,0.2) 1
# U_x(pi/4,0.2) 0
# U_z(pi,0.2) 0
# U_x(-pi/4,0.2) 1
# U_x(-pi/4,0.2) 0
# U_z(-pi,0.2) 0
# U_z(pi/2,0.2) 0
# I 1
# U_x(-pi/4,0.2) 1
# U_x(-pi/4,0.2) 0
# U_z(pi,0.2) 1
# U_x(pi/4,0.2) 1
# U_x(pi/4,0.2) 0
# U_z(-pi,0.2) 1
# U_z(-pi/2,0.2) 1
# RZ(-pi/2) 1
# RX(-pi/2) 1
# RZ(pi/2) 0
# RX(pi/2) 0

# %%
wf_sim = WavefunctionSimulator()
wavefunction = wf_sim.wavefunction(p)
print(wavefunction)
# Out:
# (0.8491169159+0.3515303227j)|00> + (0.2673847638-0.0065776737j)|01> + (-0.2567915412+0.1067536473j)|10> + (-0.0557417633+0.0586825075j)|11>

# %%
p=Program()
p+=H(0)
p+=Z(0)
p+=H(1)
p+=X(0)
p+=RX(np.pi/4,1)
p+=X(0)
p+=Y(0)
p+=X(0)
p+=RX(np.pi/4,1).dagger()
p+=H(1).dagger()
p+=X(0)
p+=H(0).dagger()
wf_sim = WavefunctionSimulator()
wavefunction = wf_sim.wavefunction(p)
print(wavefunction)
# Out:
# 1j|00>

# %%
sigma_x=np.array([[0,1],[1,0]])
sigma_y=np.array([[0,1j],[-1j,0]])
sigma_z=np.array([[1,0],[0,-1]])

sigmas=['X','Y','Z']

sigmas_dic={
    'X':sigma_x,
    'Y':sigma_y,
    'Z':sigma_z
}

# %%
for i in range(10000):
    state=np.array([1,0,0,0])
    a=np.random.choice(sigmas,1000,p=[1/3,1/3,1/3])
    for gate in a:
        state=np.kron(sigmas_dic[gate],sigmas_dic[gate])@state

# %%
sigma_z@np.array([1,0])
# Out:
# array([1, 0])

# %%
state
# Out:
# array([0.-1.j, 0.+0.j])

# %% [markdown]
# # Other stuff

# %%
J=100
n=50
sigma2=0.015**2
alpha=3/2*n
beta=(2/3)*J*sigma2/n

x=np.linspace(0,1,1000)
y = (1-x+(2/3)*J*sigma2**2)**(alpha-1)*(np.exp(-((1-x+(2/3)*J*sigma2**2)/beta)))*(beta**(-alpha))/sps.gamma(alpha)

s = np.random.gamma(alpha,beta, 10000)

count, bins, ignored = plt.hist(1-s, 100, density=True)
plt.xlim(0.8,1)
plt.plot(x,y)

# %%
final_x=[]
for i in range (41):
    
    temp=[lengths[i]]
    temp*=100
    
    final_x+=temp

results.reshape(41*sub_trials)

means=np.mean(results,axis=1)
standards=np.std(results,axis=1)

# %%
plt.plot(final_x,1-results.reshape(41*sub_trials),"o",ms=1)
plt.plot(lengths,1-means,"o--",ms=1)
plt.errorbar(lengths, 1-means, yerr=standards/np.sqrt(100))
# Out:
# <ErrorbarContainer object of 3 artists>
